# %%
colegiosLoja = datos[datos['Canton'] == 'LOJA']

# %%
import pandas as pd
from bokeh.plotting import figure, show, output_file
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool
from bokeh.palettes import Spectral5
from bokeh.transform import factor_cmap
output_file('prueba.html')

datos = pd.read_csv('data/colegios2.csv', encoding = 'latin-1', header=0, error_bad_lines=False)
datos.head()
# datos[['URI_Name', 'Canton']]
#colegios = datos['URI_Name']
#cantonesX = datos['Canton']
# Elimina nombres duplicados de cantones
#cantones = set(cantonesX)
# print(cantones)
#colegiosLoja = []
#for d in cantones:
    # print(d)
    # colegiosLoja.append(datos[datos['URI_Name','Canton'] == d])
    #colegiosLoja.append(datos[['URI_Name', 'Canton']])

#print(colegiosLoja)

#canton = datos[]
#print(colegios)


#for c 
# print(colegios)

#colegios[colegios['URI_Name'] == colegios['']]

# cantidadColegiosLoja = datos[['URI_Name', 'Canton']]
#datos[(datos['Canton' == 'Loja'])]['URI_Name', 'Canton']
#cantonLoja = datos['Canton'] == "Province_Loja"
#print(colegiosLoja)


# cantones = datos['Canton']
#colegios = datos['URI_Name']
#print(cantones)
#cantonesSimples = set(cantones)
#print(cantonesSimples)
#print(colegios)
#datos.keys()
#datos.head()
#print(df)
#output_file('prueba.html')
#provincia = datos['URI_Name']
# print(provincia)
#canton = datos['Canton']
#print(canton)

#p = figure(plot_width=400, plot_height=400)
#p = circle(provincia, canton, size=20, source=source)
#show(p)
#p = figure(title="Localización de colegios de la provincia de Loja", )
#filter = df['Canton'].isin(('Loja', 'Olmedo'))
#df = df[filter]
# Out:
#                                             URI_Name      Provincia  \
# 0                     COLEGIODEBACHILLERATO2DEAGOSTO  Loja_Province
# 1               COLEGIODEBACHILLERATOAGUSTINCURIPOMA  Loja_Province
# 2                      COLEGIODEBACHILLERATOLATINGUE  Loja_Province
# 3  COLEGIODEBACHILLERATOLICMIGUELANTOLIANOSALINAS...  Loja_Province
# 4          COLEGIODEBACHILLERATOPIOJARAMILLOALVARADO  Loja_Province
#
#       Canton              Parroquia  Latitud      Longitud  Nombre  \
# 0  ESPINDOLA                 ELAIRO       -4  471945949890     -79
# 1       LOJA                 GUALEL       -3  770003862500     -79
# 2     OLMEDO               LATINGUE       -3  910695867130     -79
# 3   QUILANGA  SANANTONIODELASARADAS       -4  364194784370     -79
# 4       LOJA           SANSEBASTIAN       -4    3418747970     -79
#
#       Direccion                                               Tipo  \
# 0  386668819200               COLEGIO DE BACHILLERATO  2 DE AGOSTO
# ...

# %%
datos[['URI_Name', 'Canton']]
# Out:
#                                               URI_Name        Canton
# 0                       COLEGIODEBACHILLERATO2DEAGOSTO     ESPINDOLA
# 1                 COLEGIODEBACHILLERATOAGUSTINCURIPOMA          LOJA
# 2                        COLEGIODEBACHILLERATOLATINGUE        OLMEDO
# 3    COLEGIODEBACHILLERATOLICMIGUELANTOLIANOSALINAS...      QUILANGA
# 4            COLEGIODEBACHILLERATOPIOJARAMILLOALVARADO          LOJA
# 5                        COLEGIODEBACHILLERATOQUILANGA      QUILANGA
# 6                   COLEGIODEBACHILLERATO12DEDICIEMBRE        CELICA
# 7                     COLEGIODEBACHILLERATO14DEOCTUBRE        CALVAS
# 8                   COLEGIODEBACHILLERATO18DENOVIEMBRE     SOZORANGA
# 9                     COLEGIODEBACHILLERATO27DEFEBRERO          LOJA
# 10                 COLEGIODEBACHILLERATO30DESEPTIEMBRE     GONZANAMA
# 11                   COLEGIODEBACHILLERATO8DEDICIEMBRE      CATAMAYO
# 12             COLEGIODEBACHILLERATOABDONCALDERONMUnOZ          LOJA
# ...

# %%
datos[datos.Canton == 'LOJA']
# Out:
#                                               URI_Name      Provincia Canton  \
# 1                 COLEGIODEBACHILLERATOAGUSTINCURIPOMA  Loja_Province   LOJA
# 4            COLEGIODEBACHILLERATOPIOJARAMILLOALVARADO  Loja_Province   LOJA
# 9                     COLEGIODEBACHILLERATO27DEFEBRERO  Loja_Province   LOJA
# 12             COLEGIODEBACHILLERATOABDONCALDERONMUnOZ  Loja_Province   LOJA
# 13                 COLEGIODEBACHILLERATOADOLFOVALAREZO  Loja_Province   LOJA
# 15            COLEGIODEBACHILLERATOBEATRIZCUEVADEAYORA  Loja_Province   LOJA
# 19          COLEGIODEBACHILLERATODOCTORBENJAMINCARRION  Loja_Province   LOJA
# 20            COLEGIODEBACHILLERATODREDUARDOMORAMORENO  Loja_Province   LOJA
# 21              COLEGIODEBACHILLERATODRBALTAZARAGUIRRE  Loja_Province   LOJA
# 29                        COLEGIODEBACHILLERATOELCISNE  Loja_Province   LOJA
# 34   COLEGIODEBACHILLERATOFISCOMISIONALDANIELALVARE...  Loja_Province   LOJA
# ...

# %%
datos[datos.Canton == 'SARAGURO']
# Out:
#                                               URI_Name      Provincia  \
# 93                UNIDADEDUCATIVAPEDROVICENTEMALDONADO  Loja_Province
# 107                  ESCUELADEEDUCACIONBASICALATACUNGA  Loja_Province
# 118                        COLEGIODEBACHILLERATOMANï¿½  Loja_Province
# 121  UNIDADEDUCATIVACOMUNITARIAINTERCULTURALBILINGU...  Loja_Province
# 122  UNIDADEDUCATIVACOMUNITARIAINTERCULTURALBILINGU...  Loja_Province
# 123       UECOMUNITARIAINTERCULTURALBILINGUEINKASAMANA  Loja_Province
# 124                      COLEGIODEBACHILLERATOSARAGURO  Loja_Province
# 125       COLEGIODEBACHILLERATOnUKANCHIKKAWSAYPARAPCEI  Loja_Province
# 135      UNIDADEDUCATIVAFISCOMISIONALSANJOSEDECALASANZ  Loja_Province
# 139  UNIDADEDUCATIVAFISCOMISIONALFRAYCRISTï¿½BALZAM...  Loja_Province
# 140        COLEGIODEBACHILLERATOVICENTEBASTIDASREINOSO  Loja_Province
# 141      ESCUELADEEDUCACIï¿½NBï¿½SICAORILLASDELJUBONES  Loja_Province
# ...

# %%
datos[datos.Canton == 'CATAMAYO']
# Out:
#                                               URI_Name      Provincia  \
# 11                   COLEGIODEBACHILLERATO8DEDICIEMBRE  Loja_Province
# 31       COLEGIODEBACHILLERATOEMILIANOABENDAnOGONZALEZ  Loja_Province
# 32         COLEGIODEBACHILLERATOEMILIANOORTEGAESPINOZA  Loja_Province
# 35   COLEGIODEBACHILLERATOFISCOMISIONALNUESTRASEnOR...  Loja_Province
# 53     COLEGIODEBACHILLERATOMONSLEONIDASPROAnOVILLALBA  Loja_Province
# 66             COLEGIODEBACHILLERATOPEDROVICTORFALCONI  Loja_Province
# 80                     COLEGIONACIONALNOCTURNOCATAMAYO  Loja_Province
# 88                 JOSEMARIAVELAZSJEXTENSIONN2CATAMAYO  Loja_Province
# 126        UNIDADEDUCATIVAFISCOMISIONALSANJUANBAUTISTA  Loja_Province
#
#        Canton            Parroquia  Latitud      Longitud  Nombre  \
# 11   CATAMAYO  SANPEDRODELABENDITA       -3  944030198130     -79
# 31   CATAMAYO              ELTAMBO       -4  144447994380     -79
# 32   CATAMAYO             CATAMAYO       -3  985779994200     -79
# ...

# %%
datos[datos.Canton == 'MACARA']
# Out:
#                                         URI_Name      Provincia  Canton  \
# 42               COLEGIODEBACHILLERATOLAVICTORIA  Loja_Province  MACARA
# 46                   COLEGIODEBACHILLERATOMACARA  Loja_Province  MACARA
# 73   COLEGIODEBACHILLERATORVDOJORGESANCHEZMORENO  Loja_Province  MACARA
# 103            UNIDADEDUCATIVADELMILENIO5DEJUNIO  Loja_Province  MACARA
# 111          UNIDADEDUCATIVAFISCOMISIONALMARISTA  Loja_Province  MACARA
# 159           UNIDADEDUCATIVASANTAMARIANADEJESUS  Loja_Province  MACARA
#
#                                  Parroquia  Latitud      Longitud  Nombre  \
# 42                              LAVICTORIA       -4  436721960950     -79
# 46         GENERALELOYALFARO(SANSEBASTIAN)       -4  371474135700     -79
# 73                     SABIANGO(LACAPILLA)       -4  367053430950     -79
# 103  MACARA(MANUELENRIQUERENGELSUQUILANDA)       -4  385777848530     -79
# 111  MACARA(MANUELENRIQUERENGELSUQUILANDA)       -4  375554207100     -79
# ...

# %%
datos[datos.Canton == 'CELICA']
# Out:
#                                           URI_Name      Provincia  Canton  \
# 6               COLEGIODEBACHILLERATO12DEDICIEMBRE  Loja_Province  CELICA
# 18          COLEGIODEBACHILLERATOCOMUNADOMINGUILLO  Loja_Province  CELICA
# 69          COLEGIODEBACHILLERATOPROCERJOSEPICOITA  Loja_Province  CELICA
# 76   COLEGIODEBACHILLERATOTNTEMAXIMILIANORODRIGUEZ  Loja_Province  CELICA
# 77           COLEGIODEBACHILLERATOTRECEDENOVIEMBRE  Loja_Province  CELICA
# 160                   UNIDADEDUCATIVASANTATERESITA  Loja_Province  CELICA
#
#                  Parroquia  Latitud      Longitud  Nombre     Direccion  \
# 6                   CELICA       -4  104940523070     -79  953472429000
# 18                  CELICA       -4  152612045580     -79  990111830200
# 69               CRUZPAMBA       -4  161499346540     -80     857224600
# 76   POZUL(SANJUANDEPOZUL)       -4  116750041580     -80   59027496600
# 77               SABANILLA       -4  208333502330     -80  125834188900
# ...

# %%
cantones = ['Loja', 'Saraguro', 'Catamayo', 'Macará', 'Celica']
numero = [61, 13, 9, 6, 6]

p = figure(x_range=cantones, plot_height=250, title="Número de colegios por cantones",
          toolbar_location=None, tools="")

p.vbar(x=cantones, top=numero, width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0

show(p)

# %%
tipo = ['Colegios Bachilleratos', 'Escuelas', 'Unidades Educativas']
numero = [100, 7, 51]

p = figure(x_range=tipo, plot_height=250, title="Cantidad de Colegios, Escuelas y Unidades Educativas de la provincia de Loja",
          toolbar_location=None, tools="")

p.vbar(x=tipo, top=numero, width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0

show(p)

# %%
datos[datos.Canton == 'LOJA']
# Out:
#                                               URI_Name      Provincia Canton  \
# 1                 COLEGIODEBACHILLERATOAGUSTINCURIPOMA  Loja_Province   LOJA
# 4            COLEGIODEBACHILLERATOPIOJARAMILLOALVARADO  Loja_Province   LOJA
# 9                     COLEGIODEBACHILLERATO27DEFEBRERO  Loja_Province   LOJA
# 12             COLEGIODEBACHILLERATOABDONCALDERONMUnOZ  Loja_Province   LOJA
# 13                 COLEGIODEBACHILLERATOADOLFOVALAREZO  Loja_Province   LOJA
# 15            COLEGIODEBACHILLERATOBEATRIZCUEVADEAYORA  Loja_Province   LOJA
# 19          COLEGIODEBACHILLERATODOCTORBENJAMINCARRION  Loja_Province   LOJA
# 20            COLEGIODEBACHILLERATODREDUARDOMORAMORENO  Loja_Province   LOJA
# 21              COLEGIODEBACHILLERATODRBALTAZARAGUIRRE  Loja_Province   LOJA
# 29                        COLEGIODEBACHILLERATOELCISNE  Loja_Province   LOJA
# 34   COLEGIODEBACHILLERATOFISCOMISIONALDANIELALVARE...  Loja_Province   LOJA
# ...

# %%
tipo = ['Colegios Bachilleratos', 'Escuelas', 'Unidades Educativas']
numero = [78, 3, 22]

p = figure(x_range=tipo, plot_height=250, title="Cantidad de Colegios, Escuelas y Unidades Educativas del Cantón Loja",
          toolbar_location=None, tools="")

p.vbar(x=tipo, top=numero, width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0

show(p)
